# %% [markdown]
# # 1、Jupyter Notebook
#
# + ### esc 切换至命令模式
# + ### enter 切换至输入模式
# + ### y 切换至Code模式
# + ### m 切换至Markdown模式
# + ### shift + enter 渲染Markdown模式/运行代码块  并跳到下一个代码块
# + ### ctrl + enter 运行当前代码块
# + ### alt + enter

# %% [markdown]
# # 2、one-hot vector

# %% [markdown]
# # 3、World2vec
#
# soft max
# ![image.png](attachment:image.png)
